# %%
''''
#Mounting the share is a 2 stage process:
# 1. Create a directory that will be the mount point
# 2. Mount the share to that directory

#Create the mount point:
mkdir share_name

#Mount the share:
mount_smbfs //username:password@server.name/share_name share_name/

#Unmount the share:
umount share_name

# %%
# importar biblioteca
import os
# montagem de diretório na rede a partir de um diretório local (pastalocal)
#mkdir pastaLocal
dir_destino= "pastaLocal"
if not os.path.exists(dir_destino):
    os.makedirs(dir_destino)

# %%
# achando o caminho dentro da rede - MONTANDO DIRETÓRIO NA REDE
# !mount_smbfs smb://ensi-filer02/gerpubprop$ pastaLocal/
#!umount pastaLocal/

# %%
#usage: 
# mount_smbfs [-N] [-o options] [-d mode] [-f mode] [-h] [-s] [-v]//[domain;][user[:password]@]server[/share] path
# smb://ensi-filer02/gerpubprop$
# smb://domainName;userName:password@server1/share1 ./share1

# %%
#!open smb://ensi-filer02/gerpubprop$

# %%
#TESTANDO O MONTAGEM DO DIRETÓRIO
os.listdir('/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/')
# Out:
# ['.smbdeleteAAAc47d8b5700befa98',
#  '.smbdeleteAAAc47d8b5c00befa9b',
#  '2021',
#  'Boletins',
#  '.DS_Store',
#  'Thumbs.db',
#  '.TemporaryItems',
#  '2012',
#  '2020',
#  '~$Planilha_2019.xlsx',
#  '~$CONTROLE_EDITORACAO_NGE (version 1).xlsx',
#  '~$Planilha_Status.xlsx',
#  '~$controle.xlsx',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '~$Requisicao de Estagiario (2).xlsx',
#  '~$Relatorio_julho.xlsx',
#  '~$Planilha_2019a.xlsx',
#  '~$Relatorio_agosto_modelo.xlsx',
#  'Diversos',
#  '~$Planilha_controle_2019.xlsx',
#  '~$Planilha_geral_historico.xlsx',
#  '~$RELATÓRIOS NGE 2019 (Marcela).xlsx',
#  '~$Demandas_NGE_2007_2019.xlsx',
#  '~$Controle_2020_NGE (1).xlsx',
#  '~$Controle_2020_NGE.xlsx']

# %%
# INSERIR O ANO PARA FAZER A BUSCA DAS PASTAS
ano_ref = "2018"

# %%
# método para achar os diretórios de forma recursiva
# https://qastack.com.br/programming/973473/getting-a-list-of-all-subdirectories-in-the-current-directory

def fast_scandir(dirname):
#def fast_scandir(dirname):

    # importar biblioteca
    import os
    import re
    import sys

    
    # achar somente se for diretório
    try:
        
        subfolders= [f.path for f in os.scandir(dirname) if f.is_dir()]
    except OSError as err:
        print("Oops! erro no método os.scandir deu erro")
        print("OS error: {0}".format(err))
        #return subfolders
    else:
        print("Unexpected error:", sys.exc_info()[0])
    for dirname in list(subfolders):
        try:
            #subfolders.extend(fast_scandir(dirname))
            if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
                print(dirname)
                subfolders.extend(fast_scandir(dirname))
        except ValueError:
            print("Oops!  erro no método subfolders.extend deu erro")
    return subfolders

# %%
# setando variável do local destino ====> ANO 
fileDir = r"/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/"+ano_ref+"/"

#chamando o método fast_scandir ############## TESTE ############### NÃO PRECISA RODAR
subfolders= fast_scandir(fileDir)
# Out:
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/DIRET
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/DIRET/PROTOCOLO DE ENCERRAMENTO
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/DIRET/PROTOCOLO DE ENCERRAMENTO/ID_225818_RELATÓRIO_ANUAL_DE_ATIVIDADES_SESI_SENAI_IEL_2018_Projeto_grafico (1)
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/DIRET/PROTOCOLO DE ENCERRAMENTO/ID_225818_RELATÓRIO_ANUAL_DE_ATIVIDADES_SESI_SENAI_IEL_2018_Projeto_grafico (1)/Arquivo_Acessibilidade
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/DIRET/PROTOCOLO DE ENCERRAMENTO/ID_225818_RELATÓRIO_ANUAL_DE_ATIVIDADES_SESI_SENAI_IEL_2018_Projeto_grafico (1)/Arquivos_indesign
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/DIRET/PROTOCOLO DE ENCERRAMENTO/ID_225818_RELATÓRIO_ANUAL_DE_ATIVIDADES_SESI_SENAI_IEL_2018_Projeto_grafico (1)/
Document fonts
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/232098_30 Innovating Cases/Arquivos_indesign/Pasta ID 230554 - 30 Casos de Inovação - CAPA_ing/Links
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/232098_30 Innovating Cases/Arquivos_indesign/Pasta Livro_30_Innovation_cases_2
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/232098_30 Innovating Cases/Arquivos_indesign/Pasta Livro_30_Innovation_cases_2/Document fonts
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/232098_30 Innovating Cases/Arquivos_indesign/Pasta Livro_30_Innovation_cases_2/Links
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/232098_30 Innovating Cases/Especificacao_grafica
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/232098_30 Innovating Cases/Mockup
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/232098_30 Innovating Cases/PDF_Grafica
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/232098_30 Innovating Cases/PDF_Internet
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/232098_30 Innovating Cases/PDF_Reprografia
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/Arquivo_acessibilidade
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/Arquivos Indesign
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/Arquivos Indesign/Capa
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/Arquivos Indesign/Capa/Document fonts
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/Arquivos Indesign/Capa/Links
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/Arquivos Indesign/Miolo
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/Arquivos Indesign/Miolo/Document fonts
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/Arquivos Indesign/Miolo/Links
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/Especificacoes_Grafica
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/Mockup
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/PDF_Grafica
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/PDF_Internet
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/229428_Criterios para uma nova agenda/PDF_Reprografia
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231928_Dupla_tributação_Brasil_e_os_Estados_Unidos
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231928_Dupla_tributação_Brasil_e_os_Estados_Unidos/Arquivo_acessibilidade
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231928_Dupla_tributação_Brasil_e_os_Estados_Unidos/Especificacoes_grafica
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231928_Dupla_tributação_Brasil_e_os_Estados_Unidos/Mockup
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231928_Dupla_tributação_Brasil_e_os_Estados_Unidos/PDF_Grafica
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231928_Dupla_tributação_Brasil_e_os_Estados_Unidos/PDF_Interativo
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231928_Dupla_tributação_Brasil_e_os_Estados_Unidos/PDF_Internet
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231928_Dupla_tributação_Brasil_e_os_Estados_Unidos/PDF_Reprografia
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Acessibilidade
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign
# Unexpected error: None
# /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign/ID_231637_Código_Aduaneiro_do_Mercosul - CAPA
# Oops! erro no método os.scandir deu erro
# OS error: [Errno 2] No such file or directory: '/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign/ID_231637_Código_Aduaneiro_do_Mercosul - CAPA'
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-139-cc31ab62b690> in <module>
#       3
#       4 #chamando o método fast_scandir ############## TESTE ############### NÃO PRECISA RODAR
# ----> 5 subfolders= fast_scandir(fileDir)
#
# <ipython-input-133-3fb8582d076c> in fast_scandir(dirname)
#      26             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
#      27                 print(dirname)
# ---> 28                 subfolders.extend(fast_scandir(dirname))
#      29         except ValueError:
#      30             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-133-3fb8582d076c> in fast_scandir(dirname)
#      26             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
#      27                 print(dirname)
# ---> 28                 subfolders.extend(fast_scandir(dirname))
#      29         except ValueError:
#      30             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-133-3fb8582d076c> in fast_scandir(dirname)
#      26             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
#      27                 print(dirname)
# ---> 28                 subfolders.extend(fast_scandir(dirname))
#      29         except ValueError:
#      30             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-133-3fb8582d076c> in fast_scandir(dirname)
#      26             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
#      27                 print(dirname)
# ---> 28                 subfolders.extend(fast_scandir(dirname))
#      29         except ValueError:
#      30             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-133-3fb8582d076c> in fast_scandir(dirname)
#      26             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
#      27                 print(dirname)
# ---> 28                 subfolders.extend(fast_scandir(dirname))
#      29         except ValueError:
#      30             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-133-3fb8582d076c> in fast_scandir(dirname)
#      21     else:
#      22         print("Unexpected error:", sys.exc_info()[0])
# ---> 23     for dirname in list(subfolders):
#      24         try:
#      25             #subfolders.extend(fast_scandir(dirname))
#
# UnboundLocalError: local variable 'subfolders' referenced before assignment

# %%
teste_dir='/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign/ID_231637_Código_Aduaneiro_do_Mercosul - CAPA'

subfolders_teste= [f.path for f in os.scandir(teste_dir) if f.is_dir()]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-143-c76d739a2a0f> in <module>
#       1 teste_dir='/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign/ID_231637_Código_Aduaneiro_do_Mercosul - CAPA'
#       2
# ----> 3 subfolders_teste= [f.path.join for f in os.scandir(teste_dir) if f.is_dir()]
#       4
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign/ID_231637_Código_Aduaneiro_do_Mercosul - CAPA'

# %%
teste_dir1='/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign'
teste_dir2='/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign/ID_231637_Código_Aduaneiro_do_Mercosul - CAPA'
teste_dir2='/Users/wpessoa/repositorios/portifolio_nge/pdf'

subfolders= [f.path for f in os.scandir(teste_dir2) if f.is_dir()]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-153-24ea1d4709ab> in <module>
#       2 teste_dir2='/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign/ID_231637_Código_Aduaneiro_do_Mercosul - CAPA'
#       3
# ----> 4 subfolders= [f.path for f in os.scandir(teste_dir2) if f.is_dir()]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign/ID_231637_Código_Aduaneiro_do_Mercosul - CAPA'

# %%
subfolders
# Out:
# ['/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign/ID_231637_Código_Aduaneiro_do_Mercosul - CAPA',
#  '/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231637_Código_Aduaneiro_do_Mercosul/Arquivos_indesign/ID_231637_Código_Aduaneiro_do_Mercosul - MIOLO']

# %%
print(len(subfolders))
# 2020 -> 3159 diretórios
# 2018 -> 3518 diretórios
# Out:
# 516

# %%
subfolders[100]
# Out:
# '/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2018/CNI/FLUXO EDITORIAL/225531_Guia de Propriedade Intelectual para o Jornalista'

# %%
os.uname()

# %%
# INSERIR O ANO PARA FAZER A BUSCA DAS PASTAS
# erros 2019, 2014, 2013
ano_ref = "2019"
# setando variável do local destino ====> ANO 
fileDir = r"/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/"+ano_ref+"/"

# %%
import re
import shutil


try:
    #setar variáveis apenas para arquivos pdf
    fileExt = r"pdf"
    
    
    #chamando o método fast_scandir
    
    subfolders= fast_scandir(fileDir)

    folderes=[]
    folderes_todos=[]
    num=1
    sem_protocolo=[]
    dir_destino= r"/Users/wpessoa/repositorios/pdf_nge/"+ano_ref
    if not os.path.exists(dir_destino):
        os.makedirs(dir_destino)
    
    for folder in subfolders:
        
        # alimentar o vetor com arquivos pdf 
        files_array = [_ for _ in os.listdir(folder) if _.endswith(fileExt)] 
        # se existir arquiv pdf
        if len(files_array)>0:
            # a procura é apenas nas pastas que tenham a palavra "internet" ou "web"
            if (re.search('internet', folder, re.IGNORECASE))or(re.search('web', folder, re.IGNORECASE))or (re.search('interativo', folder, re.IGNORECASE)):
                # arquivos apenas selecionados nas pastas com (internet, web,interativo)
                folderes.append(files_array)
                # controlar a quantidade de cópias
                #if num <20:
                for linha in files_array:
                    if not (re.search('spread', linha, re.IGNORECASE)):
                        if re.search('interativo', linha, re.IGNORECASE):
                            if not os.path.exists(dir_destino+"/"+"interativo"):
                                os.makedirs(dir_destino+"/"+"interativo")
                            shutil.copy2(folder +"/"+ linha, dir_destino +"/"+"interativo"+"/"+ linha)   
                        else:
                            print(folder)
                            shutil.copy2(folder +"/"+ linha, dir_destino +"/"+ linha)
                #num=num+1
            # todos os arquivos com pdf 
            folderes_todos.append(files_array)
        else:
            sem_protocolo.append(folder)
            
except ValueError or OSError:
            print("Oops!  erro no método verificar diretório ou erro no S.O.")
# Out:
# Oops!  erro no método os.scandir deu erro
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-116-0b1feedbda77> in fast_scandir(dirname)
#      12     try:
# ---> 13         subfolders= [f.path for f in os.scandir(dirname) if f.is_dir()]
#      14     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2019/CNI/PROTOCOLO_DE_ENCERRAMENTO/231928_Dupla_tributação_Brasil_e_os_Estados_Unidos/__MACOSX/Arquivos_indesign/ID_231928_Acordo_evitar_dupla_tributação_Brasil_EUA_CAPA'
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-117-43c8d17d7313> in <module>
#      10     #chamando o método fast_scandir
#      11
# ---> 12     subfolders= fast_scandir(fileDir)
#      13
#      14     folderes=[]
#
# <ipython-input-116-0b1feedbda77> in fast_scandir(dirname)
#      19             #subfolders.extend(fast_scandir(dirname))
#      20             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
# ---> 21                 subfolders.extend(fast_scandir(dirname))
#      22         except ValueError:
#      23             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-116-0b1feedbda77> in fast_scandir(dirname)
#      19             #subfolders.extend(fast_scandir(dirname))
#      20             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
# ---> 21                 subfolders.extend(fast_scandir(dirname))
#      22         except ValueError:
#      23             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-116-0b1feedbda77> in fast_scandir(dirname)
#      19             #subfolders.extend(fast_scandir(dirname))
#      20             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
# ---> 21                 subfolders.extend(fast_scandir(dirname))
#      22         except ValueError:
#      23             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-116-0b1feedbda77> in fast_scandir(dirname)
#      19             #subfolders.extend(fast_scandir(dirname))
#      20             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
# ---> 21                 subfolders.extend(fast_scandir(dirname))
#      22         except ValueError:
#      23             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-116-0b1feedbda77> in fast_scandir(dirname)
#      19             #subfolders.extend(fast_scandir(dirname))
#      20             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
# ---> 21                 subfolders.extend(fast_scandir(dirname))
#      22         except ValueError:
#      23             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-116-0b1feedbda77> in fast_scandir(dirname)
#      19             #subfolders.extend(fast_scandir(dirname))
#      20             if not (re.search("FLUXO EDITORIAL", dirname, re.IGNORECASE)):
# ---> 21                 subfolders.extend(fast_scandir(dirname))
#      22         except ValueError:
#      23             print("Oops!  erro no método subfolders.extend deu erro")
#
# <ipython-input-116-0b1feedbda77> in fast_scandir(dirname)
#      14     except OSError:
#      15         print("Oops!  erro no método os.scandir deu erro")
# ---> 16         return subfolders
#      17     for dirname in list(subfolders):
#      18         try:
#
# UnboundLocalError: local variable 'subfolders' referenced before assignment

# %%
os.path

# %%
print(folderes)
#print(len(folderes_todos))
print(subfolders[10])
print(re.search('2019', subfolders[0], re.IGNORECASE))
