# %%
''''
#Mounting the share is a 2 stage process:
# 1. Create a directory that will be the mount point
# 2. Mount the share to that directory

#Create the mount point:
mkdir share_name

#Mount the share:
mount_smbfs //username:password@server.name/share_name share_name/

#Unmount the share:
umount share_name

# %%
mkdir pastaLocal

# %%
#usage: 
# mount_smbfs [-N] [-o options] [-d mode] [-f mode] [-h] [-s] [-v]//[domain;][user[:password]@]server[/share] path
# smb://ensi-filer02/gerpubprop$
# smb://domainName;userName:password@server1/share1 ./share1

# %%
#!open smb://ensi-filer02/gerpubprop$

# %%
# achando o caminho dentro da rede - MONTANDO DIRETÓRIO NA REDE

# !mount_smbfs smb://ensi-filer02/gerpubprop$ pastaLocal/
#!umount pastaLocal/
# Out:
# mount_smbfs: could not find mount point /Users/wpessoa/repositorios/portifolio_nge/pastaLocal/pastaLocal: No such file or directory

# %%
os.listdir('/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2020/')
# Out:
# ['~$Controle_2020.xlsx',
#  'CNI',
#  'SESI',
#  '.DS_Store',
#  'SENAI',
#  'IEL',
#  'DIRET',
#  'Controle_2020_NGE.xlsx']

# %%
# importar biblioteca
import os

# método para achar os diretórios de forma recursiva

def fast_scandir(dirname):
    # achar somente se for diretório
    subfolders= [f.path for f in os.scandir(dirname) if f.is_dir()]
    for dirname in list(subfolders):
        subfolders.extend(fast_scandir(dirname))
    return subfolders

# %%
# setando variável do local destino
fileDir = r"/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2020/"
#chamando o método fast_scandir
subfolders= fast_scandir(fileDir)

# %%
print(len(subfolders))
# Out:
# 3159

# %%
subfolders[100]
# Out:
# '/Users/wpessoa/repositorios/portifolio_nge/pastaLocal/Coordenacao de Gestao Editorial/2020/CNI/FLUXO EDITORIAL/233884_Agenda Juridica/6_Final/Fechado/PDF_web'

# %%
os.uname()
# Out:
# posix.uname_result(sysname='Darwin', nodename='Mac-mini.local', release='19.6.0', version='Darwin Kernel Version 19.6.0: Tue Nov 10 00:10:30 PST 2020; root:xnu-6153.141.10~1/RELEASE_X86_64', machine='x86_64')

# %%
import re
#setar variáveis apenas para arquivos pdf
fileExt = r"pdf"
#chamando o método fast_scandir
subfolders= fast_scandir(fileDir)
folderes=[]
folderes_todos=[]
for folder in subfolders:
    # alimentar o vetor com arquivos pdf 
    files_array = [_ for _ in os.listdir(folder) if _.endswith(fileExt)] 
    # se existir arquiv pdf
    if len(files_array)>0:
        print(files_array)
        # a procura é apenas nas pastas que tenham a palavra "internet" ou "web"
        if (re.search('internet', folder, re.IGNORECASE))or(re.search('web', folder, re.IGNORECASE))or (re.search('interativo', folder, re.IGNORECASE)):
            #print("achei!!! ")
            folderes.append(files_array)
        #if re.search('2019', folder, re.IGNORECASE):
            #print("diretório")
        #alimentar variável com todos os arquivos pdf encontrados
        folderes_todos.append(files_array)
# Out:
# ['Casos de Sucesso do Inova Talentos.pdf']
# ['MBC_Custo Brasil_vCNI 2.pdf']
# ['Pesquisa_Economia_Circular_projeto_grafico_1509.pdf']
# ['ID_233908_Agenda Legislativa 2020.pdf', 'AII_2020_diagramacao_NGE (1).pdf']
# ['Logo FIEP.pdf']
# ['1602266750Origem2020.pdf', 'Minuta de Novo Produto.pdf', 'Quem_e_quem_Agosto_2020.pdf']
# ['1602266750Origem2020.pdf', 'Minuta de Novo Produto.pdf', 'Modelo.pdf']
# ['ID_233884_Agenda_Jurídica_da_Indústria_2020.pdf', '11_02_ID_233884_Agenda_Jurídica_da_Indústria_2020_2.pdf']
# ['AGENDA JURIDICA DA INDUSTRIA 2020_1.pdf', 'AGENDA JURIDICA DA INDUSTRIA 2020_INICIO_2.pdf', 'ID_233884_AGENDA_JURIDICA_DA_INDUSTRIA 2020_NGE.pdf']
# ['ID_233884_AGENDA_JURIDICA_2020_BOOK (revisão final Marcos).pdf', 'ID_233884_AGENDA_JURIDICA_2020_BOOK.pdf', 'ID_233884_AGENDA_JURIDICA_2020_BOOK_V3_NGE.pdf', 'ID_233884_AGENDA_JURIDICA_2020_V2.pdf', 'ID_233884_AGENDA_JURIDICA_2020_V2_NGE.pdf', 'ID_233884_AGENDA_JURIDICA_2020_BOOK_V4.pdf']
# ['DOC_20200228130946.pdf', 'Proposta_comercial_1332.pdf']
# ['economia_circular__-_pesquisa_cni_2.pdf']
# ['Pesquisa_Economia_Circular_projeto_grafico_op_2.pdf', 'Pesquisa_Economia_Circular_projeto_grafico_op1.pdf', 'Pesquisa_Economia_Circular_projeto_grafico)_op_0.pdf']
# ['CNI_EDITORAR 233867_EFEITOS DE GESTÃO SOBRE A PRODUTIVIDADE.pdf']
# ['ID_233895_Programas_de_ajuste.pdf']
# ['ID_233895_Programas_de_ajuste_1.pdf', 'ID_233895_Programas_de_ajuste_2.pdf', 'ID_233895_Programas_de_ajuste_3.pdf', 'ID_233895_Programas_de_ajuste_3_AREA_TECNICA.pdf']
# ['ID_233895_Programas_de_ajuste_V2.pdf', 'ID_233895_Programas_de_ajuste_v1.pdf']
# ['ID_233894_Agenda_Internacional_PG.pdf', 'ID_233896_Agenda_Internacional.pdf']
# ['AII_2020_diagramacao_v5[1].pdf', 'ID_233896_Agenda_Internacional_2020_V3.pdf', 'AII_2020_diagramacao_V4.pdf', 'AII_2020_diagramacao_NGE.pdf', 'AII_2020_diagramacao_V3.pdf', 'ID_233896_Agenda Internacional_2020_V5-2.pdf']
# ['ID_000000_Estudo_sobre_os_Códigos_de_Liberalização.pdf', 'ID_233893_O_Brasil_e_os_Códigos_de _Liberalização_da _OCDE.pdf']
# ['ID_233893_O_Brasil_e_o_códigos_de_liberalização_da_OCDE_MIOLO.pdf']
# ['ID_233893_O_Brasil_e_o_códigos_de_liberalização_da_OCDE_OP3_NGE.pdf']
# ['AII_2020_diagramacao_NGE.pdf']
# ['ID_233904_Estudo sobre Medidas compensatorias.pdf', 'ID_233904_FECHAMENTO_Estudo sobre Medidas Compensatórias.pdf']
# ['ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_V1.pdf']
# ['ID_235092_LGPD_adicional.pdf']
# ['ID_233898_Planejamento_estratégico_da_MEI.pdf']
# ['ID_233898_Planejamento_Estratégico_da_MEI_CAPA-2.pdf', 'ID_233898_Planejamento_Estrategico_da_MEI.pdf']
# ['ID_233898_Planejamento_Estrategico_da_MEI - Revisão AL.pdf', 'ID_233898_Planejamento_Estrategico_da_MEI_V2.pdf', 'ID_233898_Planejamento_Estrategico_da_MEI_V3.pdf', 'ID_233898_Planejamento_Estrategico_da_MEI_V2 - comentários DI.pdf']
# ['Planilha de custos Agenda Legislativa - assinada.pdf']
# ['Agenda_Legislativa_2020_capa_final.pdf', 'Agenda_Legislativa_2020_miolo_final.pdf']
# ['ID_233899_Caderno_de_Ações_e_Resultados_2019.pdf']
# ['3DS_Guidelines_Volume1_Branding.pdf']
# ['Política, posicionamento e tamanho do logótipo Saab.pdf']
# ['Logomarca_Guia1.pdf']
# ['cas_brand_usage_guidelines0917.pdf']
# ['21249326_BASF_DesignManual_2_2_PT.pdf']
# ['Território da marca (1).pdf']
# ['FIAP-magenta (1).pdf', 'FIAP-magenta (2).pdf', 'FIAP-magenta.pdf']
# ['Guide_Logo_Natura.pdf', 'natura - preferencial.pdf']
# ['NEXA_MONO_NEG_PANTONE (1).pdf', 'NEXA_MONO_NEG_PANTONE.pdf', 'NEXA_MONO_PANTONE (1).pdf', 'NEXA_MONO_PANTONE.pdf', 'NEXA_PREF_PANTONE.pdf', 'NEXA_SEC_PANTONE.pdf', 'Territorio.pdf']
# ['Nokia Global Partner Program Branding and Logo Guidelines 2018 FINAL.pdf']
# ['DoxDont LOGOMARCA.pdf']
# ['NEXA_Resources_PREF_PANTONE.pdf', 'Territorio.pdf']
# ['Fundo Azul.pdf', 'Fundo Branco - Com as cores especificadas.pdf', 'Manual Identidade Marca Cristália.pdf']
# ['logo_embrapii (1).pdf']
# ['manual-de-uso-da-marca-do-governo-federal-janeiro-2019_v06.pdf', 'manual-de-uso-da-marca-do-governo-federal-patrocinio-2019.pdf']
# ['Guide_Logo_Natura.pdf', 'natura - preferencial.pdf']
# ['QC - Logo Guidelines.pdf']
# ['GuiadeMarcav5.1.2.pdf']
# ['ID_233899_Caderno_de_Ações_e_Resultados_2019_V1.pdf']
# ['ID_233907_Pocket ALI 2020.pdf']
# ['ID 233907 - Pocket ALI 2020_V2 (1).pdf', 'ID 233907 - Pocket ALI 2020_V4.pdf']
# ['ID_233905_Proposta da Indústria 2020-22.pdf']
# ['Proposta da Industria 2002-2022 2020_03_04.pdf']
# ['ID_233903_Tradução dos Relatórios EUa e UE sobre distorções na China.pdf', 'ID_233903_FECHAMENTO_Tradução dos Relatórios EUA e UE sobre distorções na China.pdf']
# ['ID_233903_Tradução_dos_Relatórios_EUA_e_UE_sobre_distorções_na_China_V1.pdf']
# ['ID_233909_CIRCULAR_ECONOMY.pdf']
# ['Economia Circular_Caminho Estratégico.pdf']
# ['ID_233909_Circular_Economy.pdf']
# ['2020.03.17 - Rev Geral 33405_Cartilha_Licenciamento_Ambiental-Rev final.pdf']
# ['DOC036.pdf', 'DOC035.pdf']
# ['Agenda Legislativa parte 2.pdf', 'Agenda Legislativa Pocket.pdf', 'Agenda Legislativa Parte 1.pdf']
# ['ID 233908 - Agenda Legislativa 2020_V2_NGE.pdf']
# ['ID_235331_Enquadramento_dos_cursos_dÁgua.pdf']
# ['figura3.pdf']
# ['ID_235320_Documento_de_referência_para_implantação.pdf']
# ['ID_235353_OMC_Sem_Órgão_de_Apelação.pdf']
# ['ID_235353 - OMC Sem Orgao de Apelacao_web (Ajustes).pdf', 'ID_235353_FECHAMENTO_OMC_Sem_Órgão_de_Apelação.pdf']
# ['EstudoEconomiaDigital_DispensaCartaPresidente.pdf']
# ['ID_235354_Digitalização_da_economia.pdf']
# ['logo_100anos_PB.pdf', 'logo_100anos.pdf']
# ['Email_Carta de apresentaá∆o_ADT Reino Unido.pdf']
# ['Email_Apresentaá∆o_Arbitragem.pdf']
# ['ID_235874_Financiamento_para_Clima.pdf']
# ['ID_236021_Agenda for Japan.pdf']
# ['Email_Apresentaá∆o_Outlook.pdf']
# ['ID_235878_ADITIVO_Estudo sobre o impacto econômico.pdf']
# ['ID_235905_Proposta de regime para desonerar.pdf', 'ID_235905_ADITIVO_Proposta de regime para desonerar.pdf']
# ['Email_Aprovaá∆o_Apresentaá∆o_EstudoCAMEX.pdf']
# ['ID_235909_Nova Camex.pdf', 'ID_235909_Nova Camex_planilhanova.pdf']
# ['ID_235964_Teletrabalho no Brasil e mundo.pdf']
# ['Minuta de Novo Produto - Quem é quem no Seminário RedIndústria 2021.pdf', 'ID_236160_Minuta de Novo Produto - Quem é quem no Seminário RedIndústria 2021_A6.pdf']
# ['ID_235798_Mineração_no_Brasil_Rumo a uma indústria.pdf']
# ['ID_236025_Fortalecimento da defesa comercial.pdf']
# ['ID_236140_Garantias aos investimentos no exterior.pdf']
# ['Email_Aprensentaá∆oGarantias_Outlook.pdf']
# ['ID_236028_Reuso de efluentes.pdf', 'ID_236028_Reúso de efluentes_PDF_interativo.pdf']
# ['ID_236105_Produção sustentável de florestas nativas.pdf']
# ['ID_236125_Indústria resiliente.pdf', 'PDF_ID_236125_Indústria resiliente 2.pdf']
# ['cartilha_1 - ilustra 1 - estrutura da cartilha.pdf', 'cartilha_1 - ilustra 2 - poder da decis∆o de compra.pdf', 'cartilha_1 - ilustra 3 - N°veis.pdf', 'cartilha_1 - ilustra 4 - Pontos principais ISO.pdf', 'cartilha_1 - ilustra 5 - Etapas de implementaá∆o.pdf', 'cartilha_1 - ilustra 6 - Riscos.pdf', 'cartilha_1 - ilustra 7 - Aspectos de Sustentabilidade.pdf', 'cartilha_1 - ilustra 8 - Processo de compras.pdf', 'cartilha_1 - ilustra 9 - EstratÇgia de compras.pdf', 'cartilha_1 - ilustra 10 - Mapeamento da empresa.pdf', 'cartilha_1 - ilustra 11 - Cadeia de Valor.pdf', 'cartilha_1 - ilustra 12 - Quest‰es £teis.pdf']
# ['ID_236157_Cartilha ABNT NBR ISO 20400- compras sustentáveis (1).pdf']
# ['ID_236141_Nova lei de expatriação de mão de obra.pdf', 'Atualizada_ID_236141_Nova lei de expatriação de mão de obra.pdf']
# ['Email_Apresenta‡ÆoExpatria‡Æo_Outlook.pdf']
# ['ID_236142_O marco legal da ciencia.pdf']
# ['cartilha 2 - Ilustra_1 - Compras P£blicas.pdf', 'cartilha 2 - Ilustra_2 - Verificaá∆o de Conformidade.pdf', 'cartilha 2 - Ilustra_3 - Risco e Conformidade.pdf', 'cartilha 2 - Ilustra_4 - Requisitos de Sustentabilidade.pdf', 'cartilha 2 - Ilustra_5 - Ficha tÇcnica.pdf', 'cartilha 2 - Ilustra_6 - C°rculo Virtuoso.pdf', 'cartilha 2 - Ilustra_7 - Cadeia de Valor.pdf', 'cartilha 2 - Ilustra_8 - Riscos.pdf']
# ['ID_236158_Cartilha Compras Públicas Sustentáveis.pdf']
# ['ID_236123_A Precificação de Carbono.pdf', 'ID_236123_A Precificação de Carbono_PDF_INTERATIVO.pdf']
# ['ID_236020_Agenda Legislativa 2021 (PG).pdf']
# ['ID_236313_Pesquisa de Percepção do Corpo Diplomático 2020.pdf']
# ['Estrat.corp.de baixo carbono_Vidro_WEB.pdf']
# ['Email – Autorização Carta de Apresentação.pdf']
# ['Email_Apresentaá∆o.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235320_Documento_de_referência_para_implantação_das_DCNs_capa_grafica.pdf', 'ID_235320_Documento_de_referência_para_implantação_das_DCNs_miolo_grafica.pdf']
# ['ID_235320_Documento_de_referência_para_implantação_das_DCNs_interativo.pdf', 'ID_235320_Documento_de_referência_para_implantação_das_DCNs_interativo_spread.pdf']
# ['ID_235320_Documento_de_referência_para_implantação_das_DCNs_spread.pdf', 'ID_235320_Documento_de_referência_para_implantação_das_DCNs_web.pdf']
# ['ID_235320_Documento_de_referência_para_implantação_das_DCNs_capa_reprografia.pdf', 'ID_235320_Documento_de_referência_para_implantação_das_DCNs_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233896_Agenda Internacional_2020_capa_grafica.pdf', 'ID_233896_Agenda Internacional_2020_miolo_grafica.pdf']
# ['ID_233896_Agenda Internacional_2020_interativo.pdf']
# ['ID_233896_Agenda Internacional_2020_web.pdf']
# ['ID_233896_Agenda Internacional_2020_capa_reprografia.pdf', 'ID_233896_Agenda Internacional_2020_miolo_reprografia.pdf']
# ['brasil_japao.pdf', 'IDV_FCE horizontal.pdf', 'Logo BRICS Horizontal cor.pdf', 'Logo CEBEU Brasil-Estados Unidos_horizontal.pdf', 'LOGO CEMBRAR 2016.pdf', 'Logo CFB.pdf', 'Logo_FET.pdf', 'Logotipo_CEB 20 anos.pdf', 'MARCAS_REDECIN_GLOBO_CURVAS.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233907_Agenda_Legistaliva_2020_pocket_capa_grafica.pdf', 'ID_233907_Agenda_Legistaliva_2020_pocket_miolo_grafica.pdf']
# ['ID_233907_Agenda_Legistaliva_2020_pocket_interativo.pdf']
# ['ID_233907_Agenda_Legistaliva_2020_pocket_web.pdf']
# ['ID_233907_Agenda_Legistaliva_2020_pocket_capa_reprografia.pdf', 'ID_233907_Agenda_Legistaliva_2020_pocket_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233910_Cartilha_Licenciamento_Ambiental_capa_grafica.pdf', 'ID_233910_Cartilha_Licenciamento_Ambiental_grafica.pdf']
# ['ID_233910_Cartilha_Licenciamento_Ambiental+web.pdf']
# ['ID_233910_Cartilha_Licenciamento_Ambiental_capa_reprografia.pdf', 'ID_233910_Cartilha_Licenciamento_Ambiental_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233867_Efeitos_da_gestao_capa_grafica.pdf', 'ID_233867_Efeitos_da_gestao_miolo_grafica.pdf']
# ['ID_233867_Efeitos_da_gestão_sobre_a_produtividade_das_empresas_pdf_interativo.pdf']
# ['ID_233867_Efeitos_da_gestao_web.pdf']
# ['ID_233867_Efeitos_da_gestao_capa_reprografia.pdf', 'ID_233867_Efeitos_da_gestao_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['Agenda_Legislativa_2020_capa_grafica.pdf', 'ID_233908_Agenda_Legislativa_2020_miolo_grafica.pdf']
# ['ID_233908_Agenda_Legislativa_2020_interativo.pdf']
# ['ID_233908_Agenda_Legislativa_2020_web.pdf']
# ['Agenda_Legislativa_2020_capa_reprografia.pdf', 'ID_233908_Agenda_Legislativa_2020_miolo_reprografia.pdf']
# ['AGENDA JURIDICA DA INDUSTRIA_2020.pdf', 'Agenda_Legislativa_2019_web.pdf', 'APRESENTACAO_ Agenda Legislativa - Ícones.pdf', 'APRESENTACAO_ Agenda Legislativa.pdf', 'Páginas de APRESENTACAO_ Agenda Legislativa_2020.pdf']
# ['ID_2335555_Agenda_Legislativa_2020_NGE.pdf']
# ['Agenda_Legislativa_2020_capa_grafica.pdf', 'Agenda_Legislativa_2020_miolo_grafica.pdf']
# ['Agenda_Legislativa_2020_internet.pdf']
# ['Agenda_Legislativa_2020_capa_Reprografia.pdf', 'Agenda_Legislativa_2020_miolo_Reprografia.pdf']
# ['agenda juridica_capa_gráfica.pdf', 'agenda juridica_capa_reprografia.pdf']
# ['Book_agenda legislativa 2019_gráfica.pdf', 'Book_agenda legislativa 2019_reprografia.pdf']
# ['Book_agenda legislativa 2019_web.pdf']
# ['agenda juridica_capa_gráfica.pdf', 'agenda juridica_capa_reprografia.pdf']
# ['Book_agenda legislativa 2019_gráfica.pdf', 'Book_agenda legislativa 2019_reprografia.pdf']
# ['Book_agenda legislativa 2019_web.pdf']
# ['AGENDA JURIDICA DA INDUSTRIA_2020.pdf', 'Agenda_Legislativa_2019_web.pdf', 'APRESENTACAO_ Agenda Legislativa - Ícones.pdf', 'APRESENTACAO_ Agenda Legislativa.pdf', 'Páginas de APRESENTACAO_ Agenda Legislativa_2020.pdf']
# ['ID_2335555_Agenda_Legislativa_2020_NGE.pdf']
# ['Agenda_Legislativa_2020_capa_grafica.pdf', 'Agenda_Legislativa_2020_miolo_grafica.pdf']
# ['Agenda_Legislativa_2020_internet.pdf']
# ['Agenda_Legislativa_2020_capa_Reprografia.pdf', 'Agenda_Legislativa_2020_miolo_Reprografia.pdf']
# ['agenda juridica_capa_gráfica.pdf', 'agenda juridica_capa_reprografia.pdf']
# ['Book_agenda legislativa 2019_gráfica.pdf', 'Book_agenda legislativa 2019_reprografia.pdf']
# ['Book_agenda legislativa 2019_web.pdf']
# ['agenda juridica_capa_gráfica.pdf', 'agenda juridica_capa_reprografia.pdf']
# ['Book_agenda legislativa 2019_gráfica.pdf', 'Book_agenda legislativa 2019_reprografia.pdf']
# ['Book_agenda legislativa 2019_web.pdf']
# ['AGENDA JURIDICA DA INDUSTRIA_2020.pdf', 'Agenda_Legislativa_2019_web.pdf', 'APRESENTACAO_ Agenda Legislativa - Ícones.pdf', 'APRESENTACAO_ Agenda Legislativa.pdf', 'Páginas de APRESENTACAO_ Agenda Legislativa_2020.pdf']
# ['ID_2335555_Agenda_Legislativa_2020_NGE.pdf']
# ['Agenda_Legislativa_2020_capa_grafica.pdf', 'Agenda_Legislativa_2020_miolo_grafica.pdf']
# ['Agenda_Legislativa_2020_internet.pdf']
# ['Agenda_Legislativa_2020_capa_Reprografia.pdf', 'Agenda_Legislativa_2020_miolo_Reprografia.pdf']
# ['agenda juridica_capa_gráfica.pdf', 'agenda juridica_capa_reprografia.pdf']
# ['Book_agenda legislativa 2019_gráfica.pdf', 'Book_agenda legislativa 2019_reprografia.pdf']
# ['Book_agenda legislativa 2019_web.pdf']
# ['agenda juridica_capa_gráfica.pdf', 'agenda juridica_capa_reprografia.pdf']
# ['Book_agenda legislativa 2019_gráfica.pdf', 'Book_agenda legislativa 2019_reprografia.pdf']
# ['Book_agenda legislativa 2019_web.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233893_O_Brasil_e_o_códigos_de_liberalização_capa_grafica.pdf', 'ID_233893_O_Brasil_e_o_códigos_de_liberalização_miolo_grafica.pdf']
# ['ID_233893_O_Brasil_e_o_códigos_de_liberalização_PDF_INTERATIVO.pdf']
# ['ID_233893_O_Brasil_e_o_códigos_de_liberalização_capa_reprografia.pdf', 'ID_233893_O_Brasil_e_o_códigos_de_liberalização_miolo_reprografia.pdf']
# ['ID_233893_O_Brasil_e_o_códigos_de_liberalização_web.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233884_AGENDA_JURIDICA_2020_capa_grafica.pdf', 'ID_233884_AGENDA_JURIDICA_2020_miolo_grafica.pdf']
# ['ID_233884_AGENDA_JURIDICA_2020.pdf']
# ['ID_233884_AGENDA_JURIDICA_2020_capa_reprografia.pdf', 'ID_233884_AGENDA_JURIDICA_2020_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233898_Planejamento_Estrategico_da_MEI_miolo_grafica.pdf', 'ID_233898_Planejamento_Estratégico_da_MEI_CAPA_grafica.pdf']
# ['ID_233898_Planejamento_Estrategico_da_MEI_interativo.pdf']
# ['ID_233898_Planejamento_Estrategico_da_MEI_web.pdf']
# ['ID_233898_Planejamento_Estrategico_da_MEI_miolo_reprografia.pdf', 'ID_233898_Planejamento_Estratégico_da_MEI_CAPA_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233899_Caderno_de_Ações_e_Resultados 2019_CAPA_grafica.pdf', 'ID_233899_Caderno_de_Ações_e_Resultados_2019_MIOLO_grafica.pdf']
# ['ID_233899_Caderno_de_Ações_e_Resultados_2019_MIOLO_interativo.pdf']
# ['ID_233899_Caderno_de_Ações_e_Resultados_2019_web.pdf']
# ['ID_233899_Caderno_de_Ações_e_Resultados 2019_CAPA_reprografia.pdf', 'ID_233899_Caderno_de_Ações_e_Resultados_2019_MIOLO_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233908_Circular_Economy - CAPA_grafica.pdf', 'ID_233908_Circular_Economy - MIOLO_grafica.pdf']
# ['ID_233908_Circular_Economy - INTERATIVO.pdf']
# ['ID_233908_Circular_Economy.pdf']
# ['ID_233908_Circular_Economy - CAPA_reprografia.pdf', 'ID_233908_Circular_Economy - MIOLO_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233903_Tradução_dos_Relatórios_EUA_e_UE_capa_grafica.pdf', 'ID_233903_Tradução_dos_Relatórios_EUA_e_UE_miolo_grafica.pdf']
# ['ID_233903_Tradução_dos_Relatórios_EUA_e_UE_China - INTERATIVO.pdf']
# ['ID_233903_Tradução_dos_Relatórios_EUA_e_UE_sobre_distorções_na_China_web.pdf']
# ['ID_233903_Tradução_dos_Relatórios_EUA_e_UE_capa_reprografia.pdf', 'ID_233903_Tradução_dos_Relatórios_EUA_e_UE_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_CAPA_GRAFICA.pdf', 'ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_MIOLO_GRAFICA.pdf']
# ['ID_233904_Estudo_sobre_Medidas_Compensatórias_China_INTERATIVO.pdf']
# ['ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_WEB.pdf']
# ['ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_CAPA_REPROGRAFIA.pdf', 'ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_MIOLO_REPROGRAFIA.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235305_Impactos_Juridicos_Saida - capa_grafica.pdf', 'ID_235305_Impactos_Juridicos_Saida - miolo_grafica.pdf']
# ['ID_235305_Impactos_Juridicos_Saida - web.pdf']
# ['ID_235305_Impactos_Juridicos_Saida - capa_reprografia.pdf', 'ID_235305_Impactos_Juridicos_Saida - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235092_LGPD_capa_grafica.pdf', 'ID_235092_LGPD_miolo_grafica.pdf']
# ['ID_235092_LGPD_interativo.pdf']
# ['ID_235092_LGPD_web.pdf']
# ['ID_235092_LGPD_capa_reprografia.pdf', 'ID_235092_LGPD_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235331_Enquadramento_Cursos_dagua - capa_grafica.pdf', 'ID_235331_Enquadramento_Cursos_dagua - miolo_grafica.pdf']
# ['ID_235331_Enquadramento_Cursos_dagua - INTERATIVO.pdf']
# ['ID_235331_Enquadramento_Cursos_dagua.pdf']
# ['ID_235331_Enquadramento_Cursos_dagua - capa_reprografia.pdf', 'ID_235331_Enquadramento_Cursos_dagua - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['BO01_Pesquisa_Economia_Circular_grafica.pdf']
# ['BO01_Pesquisa_Economia_Circular_web.pdf']
# ['BO01_Pesquisa_Economia_Circular_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235502_Acordo dupla tributacao BR UK_capa_grafica.pdf', 'ID_235502_Acordo dupla tributacao BR UK_miolo_grafica.pdf']
# ['ID_235502_Acordo dupla tributacao BR UK - interativo.pdf']
# ['ID_235502_Acordo dupla tributacao BR UK_web.pdf']
# ['ID_235502_Acordo dupla tributacao BR UK_capa_reprografia.pdf', 'ID_235502_Acordo dupla tributacao BR UK_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235495_Pesquisa_de_Percepcao_capa_grafica.pdf', 'ID_235495_Pesquisa_de_Percepcao_miolo_grafica.pdf']
# ['ID_235495_Pesquisa_de_Percepcao_Interativo.pdf']
# ['ID_235495_Pesquisa_de_Percepcao_web.pdf']
# ['ID_235495_Pesquisa_de_Percepcao_capa_reprografia.pdf', 'ID_235495_Pesquisa_de_Percepcao_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235512_Agenda Ambiental_capa_grafica.pdf', 'ID_235512_Agenda Ambiental_miolo_grafica.pdf']
# ['ID_235512_Agenda Ambiental_interativo.pdf']
# ['ID_235512_Agenda Ambiental_web.pdf']
# ['ID_235512_Agenda Ambiental_capa_reprografia.pdf', 'ID_235512_Agenda Ambiental_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235353 - OMC Sem Orgao de Apelacao - capa_grafica.pdf', 'ID_235353 - OMC Sem Orgao de Apelacao - miolo_grafica.pdf']
# ['ID_235353 - OMC Sem Orgao de Apelacao - web.pdf']
# ['ID_235353 - OMC Sem Orgao de Apelacao - capa_reprografia.pdf', 'ID_235353 - OMC Sem Orgao de Apelacao - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235193_Cooperacao_regulatoria_capa_grafica.pdf', 'ID_235193_Cooperacao_regulatoria_miolo_grafica.pdf']
# ['ID_235193_Cooperacao_regulatoria_interativo.pdf']
# ['ID_235193_Cooperacao_regulatoria_web.pdf']
# ['ID_235193_Cooperacao_regulatoria_capa_reprografia.pdf', 'ID_235193_Cooperacao_regulatoria_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_225519_Modelos Aduaneiros_capa_grafica.pdf', 'ID_225519_Modelos Aduaneiros_miolo_grafica.pdf']
# ['ID_225519_Modelos Aduaneiros_web.pdf']
# ['ID_225519_Modelos Aduaneiros_capa_reprografia.pdf', 'ID_225519_Modelos Aduaneiros_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235511_Agenda EUA - capa_grafica.pdf', 'ID_235511_Agenda EUA - miolo_grafica.pdf']
# ['ID_235511_Agenda EUA - web.pdf']
# ['ID_235511_Agenda EUA - capa_reprografia.pdf', 'ID_235511_Agenda EUA - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235520_Agenda para a Alemanha_miolo_grafica.pdf', 'ID_235520_Agenda_para_Alemanha_CAPA_grafica.pdf']
# ['ID_235520_Agenda para a Alemanha_web.pdf']
# ['ID_235520_Agenda para a Alemanha_miolo_reprografia.pdf', 'ID_235520_Agenda_para_Alemanha_CAPA_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235469_Roadmap - capa eng_grafica.pdf', 'ID_235469_Roadmap - capa port_grafica.pdf', 'ID_235469_Roadmap - miolo_grafica.pdf']
# ['ID_235469_Roadmap - miolo eng_interativo.pdf', 'ID_235469_Roadmap - miolo port_interativo.pdf']
# ['ID_235469_Roadmap_eng_web.pdf', 'ID_235469_Roadmap_port_web.pdf']
# ['ID_235469_Roadmap - capa eng_reprografia.pdf', 'ID_235469_Roadmap - capa port_reprografia.pdf', 'ID_235469_Roadmap - miolo_reprografia.pdf']
# ['logo_100anos.pdf', 'logo_100anos_PB.pdf']
# ['logo_100anos.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235650_Agenda para a Argentina - miolo_grafica.pdf', 'ID_235650_Agenda_para_a_Argentina - capa_grafica.pdf']
# ['ID_235650_Agenda_para_a_Argentina-internet.pdf']
# ['ID_235650_Agenda para a Argentina - miolo_reprografia.pdf', 'ID_235650_Agenda_para_a_Argentina - capa_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235534_Agenda para o Japão_capa_grafica.pdf', 'ID_235534_Agenda para o Japão_miolo_grafica.pdf']
# ['ID_235534_Agenda para o Japão_web.pdf']
# ['ID_235534_Agenda para o Japão_capa_reprografia.pdf', 'ID_235534_Agenda para o Japão_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235651_Agenda para o BRICS_capa_grafica.pdf', 'ID_235651_Agenda para o BRICS_miolo_grafica.pdf']
# ['ID_235651_Agenda para o BRICS_web.pdf']
# ['ID_235651_Agenda para o BRICS_capa_reprografia.pdf', 'ID_235651_Agenda para o BRICS_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235142_Bioeconomia_e_a_Industria_brasileira - capa_grafica.pdf', 'ID_235142_Bioeconomia_e_a_Industria_brasileira - miolo_grafica.pdf']
# ['ID_235142_Bioeconomia_e_a_Industria_brasileira_INTERATIVO.pdf']
# ['ID_235142_Bioeconomia_e_a_Industria_brasileira_web.pdf']
# ['ID_235142_Bioeconomia_e_a_Industria_brasileira - capa_reprografia.pdf', 'ID_235142_Bioeconomia_e_a_Industria_brasileira - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235652_Agenda for the United States_capa_grafica.pdf', 'ID_235652_Agenda for the United States_miolo_grafica.pdf']
# ['ID_235652_Agenda for the United States_web.pdf']
# ['ID_235652_Agenda for the United States_capa_reprografia.pdf', 'ID_235652_Agenda for the United States_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235313_Protocolo de Nagoia - capa_grafica.pdf', 'ID_235313_Protocolo de Nagoia - miolo_grafica.pdf']
# ['ID_235313_Protocolo_de_Nagoia_interativo.pdf']
# ['ID_235313_Protocolo de Nagoia - web.pdf']
# ['ID_235313_Protocolo de Nagoia - capa_reprografia.pdf', 'ID_235313_Protocolo de Nagoia - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235665_Normas e Politicas de Uso - CAPA_grafica.pdf', 'ID_235665_Normas e Politicas de Uso - MIOLO_Grafica.pdf']
# ['ID_235665_Normas e Politicas de Uso_web.pdf']
# ['ID_235665_Normas e Politicas de Uso - CAPA_reprografia.pdf', 'ID_235665_Normas e Politicas de Uso - MIOLO_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235664_Governanca de Dados - capa_grafica.pdf', 'ID_235664_Governanca de Dados - miolo_grafica.pdf']
# ['ID_235664_Governanca de Dados - web.pdf']
# ['ID_235664_Governanca de Dados - capa_reprografia.pdf', 'ID_235664_Governanca de Dados - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235810_Agenda para a China - capa_grafica.pdf', 'ID_235810_Agenda para a China - miolo_grafica.pdf']
# ['ID_235810_Agenda para a China - internet.pdf']
# ['ID_235810_Agenda para a China - capa_reprografia.pdf', 'ID_235810_Agenda para a China - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235874_Financiamento para Clima_capa_grafica.pdf', 'ID_235874_Financiamento para Clima_miolo_grafica.pdf']
# ['ID_235874_Financiamento para Clima_interativo.pdf']
# ['ID_235874_Financiamento para Clima_web.pdf']
# ['ID_235874_Financiamento para Clima_capa_reprografia.pdf', 'ID_235874_Financiamento para Clima_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235382_Manual de Eventos - capa_grafica.pdf', 'ID_235382_Manual de Eventos_miolo_grafica.pdf']
# ['ID_235382_Manual de Eventos_miolo - INTERATIVO.pdf']
# ['ID_235382_Manual de Eventos - internet.pdf']
# ['ID_235382_Manual de Eventos - capa_reprografia.pdf', 'ID_235382_Manual de Eventos_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235878_Estudo sobre o impacto econômico_capa_grafica.pdf', 'ID_235878_Estudo sobre o impacto econômico_miolo_grafica.pdf']
# ['ID_235878_Estudo sobre o impacto econômico - interativo.pdf']
# ['ID_235878_Estudo sobre o impacto econômico_web.pdf']
# ['ID_235878_Estudo sobre o impacto econômico_capa_reprografia.pdf', 'ID_235878_Estudo sobre o impacto econômico_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235904_Agenda Ambiental_capa_grafica.pdf', 'ID_235904_Agenda Ambiental_miolo_grafica.pdf']
# ['ID_235904_Agenda Ambiental_interativo.pdf']
# ['ID_235904_Agenda Ambiental_web.pdf']
# ['ID_235904_Agenda Ambiental_capa_reprografia.pdf', 'ID_235904_Agenda Ambiental_miolo_reprografia.pdf']
# ['Minuta de Novo Produto - Quem é quem no Seminário RedIndústria 2021.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235909_Nova Camex - capa_grafica.pdf', 'ID_235909_Nova Camex - miolo_grafica.pdf']
# ['ID_235909_Nova Camex_web.pdf']
# ['ID_235909_Nova Camex - capa_reprografia.pdf', 'ID_235909_Nova Camex - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235876_Agenda for Germany - miolo_grafica.pdf', 'ID_235876_Agenda for Germany_CAPA_grafica.pdf']
# ['ID_235876_Agenda for Germany_web.pdf']
# ['ID_235876_Agenda for Germany - miolo_reprografia.pdf', 'ID_235876_Agenda for Germany_CAPA_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235880_Agenda para o Mexico - capa_grafica.pdf', 'ID_235880_Agenda para o Mexico - miolo_grafica.pdf']
# ['ID_235880_Agenda para o Mexico_web.pdf']
# ['ID_235880_Agenda para o Mexico - capa_reprografia.pdf', 'ID_235880_Agenda para o Mexico - miolo_reprografia.pdf']
# ['ID_235881_Agenda para o Reino Unido - capa_grafica.pdf', 'ID_235881_Agenda para o Reino Unido - capa_reprografia.pdf', 'ID_235881_Agenda para o Reino Unido - miolo_grafica.pdf', 'ID_235881_Agenda para o Reino Unido - miolo_reprografia.pdf', 'ID_235881_Agenda para o Reino Unido - web.pdf']
# ['Especificacao_grafica.pdf']
# [' ID 236105 - Produção sustentável de florestas nativas - capa_grafica.pdf', ' ID 236105 - Produção sustentável de florestas nativas - miolo_grafica.pdf']
# [' ID 236105 - Produção sustentável de florestas nativas.pdf']
# [' ID 236105 - Produção sustentável de florestas nativas - capa_reprografia.pdf', ' ID 236105 - Produção sustentável de florestas nativas - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233908_Agenda_Legislativa_2020_capa_grafica.pdf', 'ID_233908_Agenda_Legislativa_2020_miolo_grafica.pdf']
# ['ID_233908_Agenda_Legislativa_2020_web.pdf']
# ['ID_233908_Agenda_Legislativa_2020_capa_reprografia.pdf', 'ID_233908_Agenda_Legislativa_2020_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID 236028_Reuso de efluentes para abastecimento - capa_grafica.pdf', 'ID 236028_Reuso de efluentes para abastecimento - miolo_grafica.pdf']
# ['ID 236028_Reuso de efluentes para abastecimento - interativo.pdf']
# ['ID 236028_Reuso de efluentes para abastecimento - web.pdf']
# ['ID 236028_Reuso de efluentes para abastecimento - capa_reprografia.pdf', 'ID 236028_Reuso de efluentes para abastecimento - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236141_Nova lei de expatriação de mão de obra - capa_grafica.pdf', 'ID_236141_Nova lei de expatriação de mão de obra - miolo_grafica.pdf']
# ['ID_236141_Nova lei de expatriação de mão de obra_interativo.pdf']
# ['ID_236141_Nova lei de expatriação de mão de obra_web.pdf']
# ['ID_236141_Nova lei de expatriação de mão de obra - capa_reprografia.pdf', 'ID_236141_Nova lei de expatriação de mão de obra - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236338_A prática brasileira em defesa comercial - capa_grafica.pdf', 'ID_236338_A prática brasileira em defesa comercial - miolo_grafica.pdf']
# ['ID_236338_A prática brasileira em defesa comercial - web.pdf']
# ['ID_236338_A prática brasileira em defesa comercial - capa_reprografia.pdf', 'ID_236338_A prática brasileira em defesa comercial - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233903_Tradução_dos_Relatórios_EUA_e_UE_capa_grafica.pdf', 'ID_233903_Tradução_dos_Relatórios_EUA_e_UE_miolo_grafica.pdf']
# ['ID_233903_Tradução_dos_Relatórios_EUA_e_UE_China - INTERATIVO.pdf']
# ['ID_233903_Tradução_dos_Relatórios_EUA_e_UE_sobre_distorções_na_China_web.pdf']
# ['ID_233903_Tradução_dos_Relatórios_EUA_e_UE_capa_reprografia.pdf', 'ID_233903_Tradução_dos_Relatórios_EUA_e_UE_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_CAPA_GRAFICA.pdf', 'ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_MIOLO_GRAFICA.pdf']
# ['ID_233904_Estudo_sobre_Medidas_Compensatórias_China_INTERATIVO.pdf']
# ['ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_WEB.pdf']
# ['ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_CAPA_REPROGRAFIA.pdf', 'ID_233904_Estudo_sobre_Medidas_Compensatórias_aplicadas_contra_a_China_MIOLO_REPROGRAFIA.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236313_Pesquisa_de_Percepcao - capa_Grafica.pdf', 'ID_236313_Pesquisa_de_Percepcao - miolo_Grafica.pdf']
# ['ID_236313_Pesquisa_de_Percepcao - web.pdf']
# ['ID_236313_Pesquisa_de_Percepcao - capa_reprografia.pdf', 'ID_236313_Pesquisa_de_Percepcao - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235353 - OMC Sem Orgao de Apelacao - capa_grafica.pdf', 'ID_235353 - OMC Sem Orgao de Apelacao - miolo_grafica.pdf']
# ['ID_235353 - OMC Sem Orgao de Apelacao - web.pdf']
# ['ID_235353 - OMC Sem Orgao de Apelacao - capa_reprografia.pdf', 'ID_235353 - OMC Sem Orgao de Apelacao - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_235905_Proposta de regime para as importacoes_capa_grafica.pdf', 'ID_235905_Proposta de regime para as importacoes_miolo_grafica.pdf']
# ['ID_235905_Proposta de regime para as importacoes_web.pdf']
# ['ID_235905_Proposta de regime para as importacoes_capa_reprografia.pdf', 'ID_235905_Proposta de regime para as importacoes_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236021_Agenda for Japan - capa_grafica.pdf', 'ID_236021_Agenda for Japan - miolo_grafica.pdf']
# ['ID_236021_Agenda for Japan - web.pdf']
# ['ID_236021_Agenda for Japan - capa_reprografia.pdf', 'ID_236021_Agenda for Japan - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236157_Cartilha ABNT NBR ISO 20400 - capa_grafica.pdf', 'ID_236157_Cartilha ABNT NBR ISO 20400 - miolo_Grafica.pdf']
# ['ID_236157_Cartilha ABNT NBR ISO 20400 - interativo.pdf']
# ['ID_236157_Cartilha ABNT NBR ISO 20400 - web.pdf']
# ['ID_236157_Cartilha ABNT NBR ISO 20400 - capa_reprografia.pdf', 'ID_236157_Cartilha ABNT NBR ISO 20400 - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236158_Cartilha Compras Públicas Sustentáveis - capa_grafica.pdf', 'ID_236158_Cartilha Compras Públicas Sustentáveis - miolo_grafica.pdf']
# ['ID_236158_Cartilha Compras Públicas Sustentáveis - INTERATIVO.pdf']
# ['ID_236158_Cartilha Compras Públicas Sustentáveis - web.pdf']
# ['ID_236158_Cartilha Compras Públicas Sustentáveis - capa_reprografia.pdf', 'ID_236158_Cartilha Compras Públicas Sustentáveis - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236339_O modelo brasileiro de acordos_capa grafica.pdf', 'ID_236339_O modelo brasileiro de acordos_miolo grafica.pdf']
# ['ID_236339_O modelo brasileiro de acordos_web.pdf']
# ['ID_236339_O modelo brasileiro de acordos_capa_reprografia.pdf', 'ID_236339_O modelo brasileiro de acordos_miolo reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236323_Consulta sobre Licenciamento_grafica.pdf']
# ['ID_236323_Consulta sobre Licenciamento_web.pdf']
# ['ID_236323_Consulta sobre Licenciamento_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236142_O marco legal de ciência - capa_grafica.pdf', 'ID_236142_O marco legal de ciência - miolo_grafica.pdf']
# ['ID_236142_O marco legal de ciência - INTERATIVO.pdf']
# ['ID_236142_O marco legal de ciência - web.pdf']
# ['ID_236142_O marco legal de ciência - capa_reprografia.pdf', 'ID_236142_O marco legal de ciência - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_193359_Estratégias Corporativas de Baixo Carbono_capa_grafica.pdf', 'ID_193359_Estratégias Corporativas de Baixo Carbono_miolo_grafica.pdf']
# ['ID_193359_Estratégias Corporativas de Baixo Carbono_web.pdf']
# ['ID_193359_Estratégias Corporativas de Baixo Carbono_capa_reprografia.pdf', 'ID_193359_Estratégias Corporativas de Baixo Carbono_miolo_reprografia.pdf']
# ['Especificações do Programa Brasileiro GHG Protocol.pdf', 'Figura 14.pdf', 'Figura 22.pdf', 'Figura 30.pdf', 'Figura 8.pdf', 'Figura 9.pdf', 'Páginas de Quadro 1 - Guia CNI - Setor do Vidro.pdf', 'The Greenhouse Gas Protocol.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236455_Programas estatais da China_capa_grafica.pdf', 'ID_236455_Programas estatais da China_miolo_grafica.pdf']
# ['ID_236455_Programas estatais da China_web.pdf']
# ['ID_236455_Programas estatais da China_capa_reprografia.pdf', 'ID_236455_Programas estatais da China_miolo_reprografia.pdf']
# ['ABAL-marca.pdf']
# ['ABAL-marca cinza.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236527_Encargos do setor elétrico_capa_grafica.pdf', 'ID_236527_Encargos do setor elétrico_miolo_grafica.pdf']
# ['ID_236527_Encargos do setor elétrico_web.pdf']
# ['ID_236527_Encargos do setor elétrico_capa_reprografia.pdf', 'ID_236527_Encargos do setor elétrico_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_236534_NR1_capa_grafica.pdf', 'ID_236534_NR1_miolo_grafica.pdf']
# ['ID_236534_NR1_web.pdf']
# ['ID_236534_NR1_capa_reprografia.pdf', 'ID_236534_NR1_miolo_reprografia.pdf']
# ['SESI_APRES (3).pdf', 'Capas_itinerários.pdf']
# ['ID_233839_Competicoes_cientificas_NGE.pdf']
# ['ID_235981B_EJA_Anos finais_2.pdf', 'ID_235983B_EJA anos iniciais_2.pdf', 'ID_235984B_EJA ensino médio_2.pdf']
# ['ID_236121_Proposta pedagógica_Ensino fundamental.pdf']
# ['Documentos Norteadores com Prioridade de Entrega_para envio.pdf', 'Planilhas_aprovadas.pdf']
# ['ID_233839_Competicoes_cientificas_NGE.pdf']
# ['ID_233839_Competicoes cientificas (1).pdf']
# ['ID_233906_Panorama_Rede_SESI.pdf']
# ['ID_236031_Proposta_pedagogica_da_EI.pdf']
# ['proposta_comercial_1339.pdf']
# ['BO05_SESI_guide_to_prevent_COVID-19_V2_spread.pdf']
# ['GUIA SESI DE PREVENÇÃO À COVID NAS EMPRESAS - VS 5.0.pdf']
# ['Planilha atualizada_EF- FINAIS-EDITORAR.pdf']
# ['ID_235985_Ensino Fundamental - ANOS FINAIS.pdf']
# ['ID_235986_Ensino Fundamental - ANOS INICIAIS.pdf', 'Planilha atualizada_EF-EDITORAR-INICIAIS.pdf']
# ['ID236159_Cronograma_Violência Autoprovocada.pdf']
# ['ID_236162_Guia SESI para retorno às aulas.pdf']
# ['Especificacao_grafica.pdf']
# ['ID 235986_Ensino Fundamental Anos Iniciais - capa_grafica.pdf', 'ID 235986_Ensino Fundamental Anos Iniciais - miolo_grafica.pdf']
# ['ID 235986_Ensino Fundamental Anos Iniciais - web.pdf']
# ['ID 235986_Ensino Fundamental Anos Iniciais - capa_reprografia.pdf', 'ID 235986_Ensino Fundamental Anos Iniciais - miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['ID_233839_Competicoes_cientificas_capa_grafica.pdf', 'ID_233839_Competicoes_cientificas_miolo_grafica.pdf']
# ['ID_233839_Competicoes_cientificas - INTERATIVO.pdf']
# ['ID_233839_Competicoes_cientificas_web.pdf']
# ['ID_233839_Competicoes_cientificas_capa_reprografia.pdf', 'ID_233839_Competicoes_cientificas_miolo_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['Recomendações SESI_grafica.pdf']
# ['Recomendações SESI_spread.pdf', 'Recomendações SESI_web.pdf']
# ['Recomendações SESI_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['BO04_Cartilha_Guia_SESI_de_Saude_mental_grafica.pdf']
# ['BO04_Cartilha_Guia_SESI_de_Saude_mental_spread.pdf', 'BO04_Cartilha_Guia_SESI_de_Saude_mental_web.pdf']
# ['BO04_Cartilha_Guia_SESI_de_Saude_mental_reprografia.pdf']
# ['Especificacao_grafica.pdf']
# ['BO06_Guía_de_prevención_SESI COVID-19_grafica.pdf']
# ['BO06_Guía_de_prevención_SESI COVID-19_spread.pdf', 'BO06_Guía_de_prevención_SESI COVID-19_web.pdf']
# ['BO06_Guía_de_prevención_SESI COVID-19_reprografia.pdf']

# %%
print(folderes)
#print(len(folderes_todos))
print(subfolders[10])
print(re.search('2019', subfolders[0], re.IGNORECASE))
# Out:
# [['ID_233908_Agenda_Legislativa_2020_web.pdf'], ['ID_233908_Agenda_Legislativa_2020_interativo.pdf'], ['ID_193359_Estratégias Corporativas de Baixo Carbono_web.pdf']]
# /Users/wpessoa/repositorios/portifolio_nge/pdf/2020/CNI/PROTOCOLO DE ENCERRAMENTO/233555_Agenda Legislativa da Industria/Arquivo_indesign
# <re.Match object; span=(47, 51), match='2019'>
